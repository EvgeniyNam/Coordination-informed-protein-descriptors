# %% [markdown]
# # Processing energies

# %% [markdown]
# Here we process extracted data to get interaction energies:

# %%
# imports
import pandas as pd

# %%
# loading data
df = pd.read_csv('data/total_energies.csv')
df
# Out:
#                                                 Mainfile       Formula  \
# 0      AminoAcids/glu/Dipeptide/Ba/conf_0047/FHIaims.out   BaC8H13N2O4
# 1      AminoAcids/argH/Dipeptide/bare/conf_0855/FHIai...     C9H20N5O2
# 2      AminoAcids/lysH/Dipeptide/bare/conf_0528/FHIai...     C9H20N3O2
# 3      AminoAcids/lys/Dipeptide/bare/conf_1802/FHIaim...     C9H19N3O2
# 4      AminoAcids/met/Dipeptide/Ca/conf_0159/FHIaims.out  C8CaH16N2O2S
# ...                                                  ...           ...
# 23235  AminoAcids/lysH/Dipeptide/Mg/conf_0180/FHIaims...   C9H20MgN3O2
# 23236  AminoAcids/lysH/Dipeptide/Ba/conf_0189/FHIaims...   BaC9H20N3O2
# 23237  AminoAcids/lysH/Dipeptide/Ba/conf_0539/FHIaims...   BaC9H20N3O2
# 23238  AminoAcids/arg/Dipeptide/bare/conf_2884/FHIaim...     C9H19N5O2
# 23239  AminoAcids/arg/Dipeptide/Mg/conf_0285/FHIaims.out   C9H19MgN5O2
#
#                            Entry_ID               Upload_ID   Total_energy
# 0      ---sV-GhvU9x9aLIxYIaSaRRMYb7  OhCdHFfSTLu8g6CGBISk4w -244828.848890
# 1      --6kkazavrym5kv8a9t9i9xFsVUY  MTSFEw9oS1GRiY0LVMgOYw  -21201.159951
# 2      --DqMR6pHAuouHktSJGR58iTBYmm  SXdit6b0RtibOeWIk3dulw  -18219.475813
# 3      --GsPYTZbOQDIzkGgdrzmr_40vc4  hSvqxrr0RjOhzwYU0stsOg  -18209.078055
# 4      --PlSeBOD6yCTDHBSdgPE5cEdzof  oHhmKWH2RHyyq7I2_Zdtkg  -45055.995082
# ...                             ...                     ...            ...
# 23235  zyGRZ-2zfy1iCrFASB2RxClsAswM  3mF4CEoTReGHEdeR4sFfnw  -23655.925188
# 23236  zyY1Y-fXObAwli-dLx4uzH3hzuef  ZnZLnzQUTbiqfI_XO3s4Aw -243352.333824
# 23237  zy_65vIS9xvjArhxdHziwln8IIr4  ZnZLnzQUTbiqfI_XO3s4Aw -243351.595025
# 23238  zymyALFYVstb5DXBA3b6I5I2MBOI  N-T_ymXOSk-DXMIjvGyFrQ  -21190.209803
# 23239  zzFI-iLg4I6FyTMYfzo0Xdk-N37Z  NIDpEFBaRuiPEiQKAUxB7g  -26633.139539
#
# [23240 rows x 5 columns]

# %%
# get metal and aminoacid
df['Aminoacid'] = df['Mainfile'].apply(lambda x: x.split('/')[1])
df['Cation'] = df['Mainfile'].apply(lambda x: x.split('/')[3])
df = df[['Aminoacid', 'Cation', 'Total_energy']]
df
# Out:
#       Aminoacid Cation   Total_energy
# 0           glu     Ba -244828.848890
# 1          argH   bare  -21201.159951
# 2          lysH   bare  -18219.475813
# 3           lys   bare  -18209.078055
# 4           met     Ca  -45055.995082
# ...         ...    ...            ...
# 23235      lysH     Mg  -23655.925188
# 23236      lysH     Ba -243352.333824
# 23237      lysH     Ba -243351.595025
# 23238       arg   bare  -21190.209803
# 23239       arg     Mg  -26633.139539
#
# [23240 rows x 3 columns]

# %%
# get min energies for each system
edf = df.groupby(['Aminoacid', 'Cation']).min().reset_index()
edf
# Out:
#     Aminoacid Cation   Total_energy
# 0         ala     Ba -238632.421019
# 1         ala     Ca  -32039.458764
# 2         ala     Mg  -18935.682552
# 3         ala   bare  -13494.836125
# 4         arg     Ba -246330.134028
# ..        ...    ...            ...
# 99        tyr   bare  -21829.375306
# 100       val     Ba -240771.381368
# 101       val     Ca  -34178.447579
# 102       val     Mg  -21074.870157
# 103       val   bare  -15633.672556
#
# [104 rows x 3 columns]

# %%
# pivot metals
edf = edf.pivot(index='Aminoacid', columns='Cation', values='Total_energy').reset_index().rename_axis(None, axis = 1)
edf
# Out:
#    Aminoacid             Ba            Ca            Mg          bare
# 0        ala -238632.421019 -32039.458764 -18935.682552 -13494.836125
# 1        arg -246330.134028 -39737.682035 -26634.983857 -21191.050328
# 2       argH -246335.375896 -39742.307368 -26638.421192 -21202.194401
# 3        asn -243225.964309 -36633.343923 -23530.092416 -18087.583754
# 4        asp -243759.839553 -37167.381480 -24064.153242 -18614.739237
# 5       aspH -243767.207694 -37174.548699 -24071.247717 -18629.212924
# 6        cys -249511.174067 -42918.418437 -29815.044755 -24373.456279
# 7        gln -244295.781748 -37703.200037 -24600.047854 -19156.975091
# 8        glu -244829.487512 -38237.074533 -25133.909340 -19684.239885
# 9       gluH -244837.015187 -38244.254787 -25141.055706 -19698.630019
# 10       gly -237562.813291 -30969.832555 -17866.036824 -12425.328631
# 11      hisD -244756.973675 -38164.233635 -25060.822277 -19618.868213
# 12      hisE -244757.563961 -38164.973724 -25061.930235 -19618.787237
# 13      hisH -244761.761462 -38168.617313 -25064.660117 -19629.503341
# 14       ile -241840.818767 -35247.915643 -22144.410215 -16703.063762
# 15       leu -241840.863283 -35247.921070 -22144.422363 -16703.110845
# 16       lys -243348.392756 -36755.803180 -23652.952899 -18209.791650
# 17      lysH -243353.405718 -36760.335608 -23656.448136 -18220.524333
# 18       met -251650.438030 -45057.782453 -31954.643492 -26512.300062
# 19       phe -244919.348047 -38326.679514 -25223.260891 -19780.913192
# 20       pro -240738.686812 -34145.760213 -21042.006987 -15600.951811
# 21       ser -240681.003964 -34088.278725 -20984.877249 -15543.196561
# 22       thr -241750.678694 -35157.977240 -22055.190627 -16612.753167
# 23       trp -248500.387432 -41907.738212 -28804.416766 -23361.555280
# 24       tyr -246967.906666 -40375.260569 -27271.856979 -21829.375306
# 25       val -240771.381368 -34178.447579 -21074.870157 -15633.672556

# %%
# combine hisE and hisD
idxs = edf['Aminoacid'].isin(['hisD', 'hisE'])
his = {c: edf.loc[idxs, c].min() for c in edf.columns[1:]}
his['Aminoacid'] = 'his'

# sub hisE and hisD with his
edf = pd.concat([edf.loc[~idxs], pd.DataFrame([his])], ignore_index=True).sort_values('Aminoacid', ignore_index=True)
edf
# Out:
#    Aminoacid             Ba            Ca            Mg          bare
# 0        ala -238632.421019 -32039.458764 -18935.682552 -13494.836125
# 1        arg -246330.134028 -39737.682035 -26634.983857 -21191.050328
# 2       argH -246335.375896 -39742.307368 -26638.421192 -21202.194401
# 3        asn -243225.964309 -36633.343923 -23530.092416 -18087.583754
# 4        asp -243759.839553 -37167.381480 -24064.153242 -18614.739237
# 5       aspH -243767.207694 -37174.548699 -24071.247717 -18629.212924
# 6        cys -249511.174067 -42918.418437 -29815.044755 -24373.456279
# 7        gln -244295.781748 -37703.200037 -24600.047854 -19156.975091
# 8        glu -244829.487512 -38237.074533 -25133.909340 -19684.239885
# 9       gluH -244837.015187 -38244.254787 -25141.055706 -19698.630019
# 10       gly -237562.813291 -30969.832555 -17866.036824 -12425.328631
# 11       his -244757.563961 -38164.973724 -25061.930235 -19618.868213
# 12      hisH -244761.761462 -38168.617313 -25064.660117 -19629.503341
# 13       ile -241840.818767 -35247.915643 -22144.410215 -16703.063762
# 14       leu -241840.863283 -35247.921070 -22144.422363 -16703.110845
# 15       lys -243348.392756 -36755.803180 -23652.952899 -18209.791650
# 16      lysH -243353.405718 -36760.335608 -23656.448136 -18220.524333
# 17       met -251650.438030 -45057.782453 -31954.643492 -26512.300062
# 18       phe -244919.348047 -38326.679514 -25223.260891 -19780.913192
# 19       pro -240738.686812 -34145.760213 -21042.006987 -15600.951811
# 20       ser -240681.003964 -34088.278725 -20984.877249 -15543.196561
# 21       thr -241750.678694 -35157.977240 -22055.190627 -16612.753167
# 22       trp -248500.387432 -41907.738212 -28804.416766 -23361.555280
# 23       tyr -246967.906666 -40375.260569 -27271.856979 -21829.375306
# 24       val -240771.381368 -34178.447579 -21074.870157 -15633.672556

# %%
# compute interaction energies
for M in ('Mg', 'Ca', 'Ba'):
    edf[f'E_{M}'] = edf[M] - edf['bare']
    edf[f'E_{M}'] = edf[f'E_{M}'] - edf.loc[edf['Aminoacid'] == 'gly', f'E_{M}'].values[0]
edf = edf[['Aminoacid', 'E_Mg', 'E_Ca', 'E_Ba']]
edf
# Out:
#    Aminoacid      E_Mg      E_Ca      E_Ba
# 0        ala -0.138234 -0.118715 -0.100234
# 1        arg -3.225336 -2.127782 -1.599040
# 2       argH  4.481403  4.390957  4.303165
# 3        asn -1.800469 -1.256246 -0.895895
# 4        asp -8.705812 -8.138319 -7.615657
# 5       aspH -1.326600 -0.831851 -0.510109
# 6        cys -0.880283 -0.458234 -0.233128
# 7        gln -2.364570 -1.721022 -1.321998
# 8        glu -8.961262 -8.330724 -7.762967
# 9       gluH -1.717493 -1.120843 -0.900507
# 10       gly  0.000000  0.000000  0.000000
# 11       his -2.353829 -1.601587 -1.211088
# 12      hisH  5.551417  5.389953  5.226539
# 13       ile -0.638260 -0.347956 -0.270345
# 14       leu -0.603325 -0.306301 -0.267777
# 15       lys -2.453055 -1.507605 -1.116446
# 16      lysH  4.784390  4.692650  4.603275
# 17       met -1.635237 -0.978467 -0.653308
# 18       phe -1.639505 -1.262397 -0.950195
# 19       pro -0.346983 -0.304477 -0.250341
# 20       ser -0.972495 -0.578240 -0.322743
# 21       thr -1.729267 -0.720148 -0.440866
# 22       trp -2.153293 -1.679008 -1.347492
# 23       tyr -1.773480 -1.381339 -1.046700
# 24       val -0.489408 -0.271099 -0.224152

# %%
# extract ionic systems sidechains
ions = ['lysH', 'argH', 'hisH', 'asp', 'glu']
charged = edf.loc[edf['Aminoacid'].isin(ions)].reset_index(drop=True)
edf = edf.loc[~edf['Aminoacid'].isin(ions)].reset_index(drop=True)
len(edf), len(charged)
# Out:
# (20, 5)

# %%
# remove 'H' from aminoacid names
for x in (edf, charged):
    x.loc[:,'Aminoacid'] = x['Aminoacid'].str.replace('H', '')
charged = charged.rename(columns = {f'E_{M}': f'E_{M}_ion' for M in ('Mg', 'Ca', 'Ba')})
charged
# Out:
#   Aminoacid  E_Mg_ion  E_Ca_ion  E_Ba_ion
# 0       arg  4.481403  4.390957  4.303165
# 1       asp -8.705812 -8.138319 -7.615657
# 2       glu -8.961262 -8.330724 -7.762967
# 3       his  5.551417  5.389953  5.226539
# 4       lys  4.784390  4.692650  4.603275

# %%
# add columns for ionized sidechains
for M in ('Mg', 'Ca', 'Ba'):
    edf[f'E_{M}_ion'] = edf[f'E_{M}']

# substitute values for ionised AAs
idxs = edf['Aminoacid'].isin(charged['Aminoacid'])
cols = [f'E_{M}_ion'  for M in ('Mg', 'Ca', 'Ba')]
charged.index = edf.loc[idxs, cols].index
edf.loc[idxs, cols] = charged.loc[:, cols]
edf
# Out:
#    Aminoacid      E_Mg      E_Ca      E_Ba  E_Mg_ion  E_Ca_ion  E_Ba_ion
# 0        ala -0.138234 -0.118715 -0.100234 -0.138234 -0.118715 -0.100234
# 1        arg -3.225336 -2.127782 -1.599040  4.481403  4.390957  4.303165
# 2        asn -1.800469 -1.256246 -0.895895 -1.800469 -1.256246 -0.895895
# 3        asp -1.326600 -0.831851 -0.510109 -8.705812 -8.138319 -7.615657
# 4        cys -0.880283 -0.458234 -0.233128 -0.880283 -0.458234 -0.233128
# 5        gln -2.364570 -1.721022 -1.321998 -2.364570 -1.721022 -1.321998
# 6        glu -1.717493 -1.120843 -0.900507 -8.961262 -8.330724 -7.762967
# 7        gly  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8        his -2.353829 -1.601587 -1.211088  5.551417  5.389953  5.226539
# 9        ile -0.638260 -0.347956 -0.270345 -0.638260 -0.347956 -0.270345
# 10       leu -0.603325 -0.306301 -0.267777 -0.603325 -0.306301 -0.267777
# 11       lys -2.453055 -1.507605 -1.116446  4.784390  4.692650  4.603275
# 12       met -1.635237 -0.978467 -0.653308 -1.635237 -0.978467 -0.653308
# 13       phe -1.639505 -1.262397 -0.950195 -1.639505 -1.262397 -0.950195
# 14       pro -0.346983 -0.304477 -0.250341 -0.346983 -0.304477 -0.250341
# 15       ser -0.972495 -0.578240 -0.322743 -0.972495 -0.578240 -0.322743
# 16       thr -1.729267 -0.720148 -0.440866 -1.729267 -0.720148 -0.440866
# 17       trp -2.153293 -1.679008 -1.347492 -2.153293 -1.679008 -1.347492
# 18       tyr -1.773480 -1.381339 -1.046700 -1.773480 -1.381339 -1.046700
# 19       val -0.489408 -0.271099 -0.224152 -0.489408 -0.271099 -0.224152

# %%
# one-letter AA names
AAs = {'ala': 'A', 'arg': 'R', 'asn': 'N', 'asp': 'D',
       'val': 'V', 'his': 'H', 'gly': 'G', 'gln': 'Q',
       'glu': 'E', 'ile': 'I', 'leu': 'L', 'lys': 'K',
       'met': 'M', 'pro': 'P', 'ser': 'S', 'tyr': 'Y',
       'thr': 'T', 'trp': 'W', 'phe': 'F', 'cys': 'C'}
edf['Aminoacid'] = edf['Aminoacid'].replace(AAs)
edf.columns = ['Aminoacid'] + [f'{M} interaction energy, eV' for M in ('Mg', 'Ca', 'Ba')] + \
              [f'{M} interaction energy, charged sidechains, eV' for M in ('Mg', 'Ca', 'Ba')]
edf
# Out:
#    Aminoacid  Mg interaction energy, eV  Ca interaction energy, eV  \
# 0          A                  -0.138234                  -0.118715
# 1          R                  -3.225336                  -2.127782
# 2          N                  -1.800469                  -1.256246
# 3          D                  -1.326600                  -0.831851
# 4          C                  -0.880283                  -0.458234
# 5          Q                  -2.364570                  -1.721022
# 6          E                  -1.717493                  -1.120843
# 7          G                   0.000000                   0.000000
# 8          H                  -2.353829                  -1.601587
# 9          I                  -0.638260                  -0.347956
# 10         L                  -0.603325                  -0.306301
# 11         K                  -2.453055                  -1.507605
# 12         M                  -1.635237                  -0.978467
# 13         F                  -1.639505                  -1.262397
# 14         P                  -0.346983                  -0.304477
# 15         S                  -0.972495                  -0.578240
# 16         T                  -1.729267                  -0.720148
# 17         W                  -2.153293                  -1.679008
# 18         Y                  -1.773480                  -1.381339
# 19         V                  -0.489408                  -0.271099
#
#     Ba interaction energy, eV  Mg interaction energy, charged sidechains, eV  \
# 0                   -0.100234                                      -0.138234
# 1                   -1.599040                                       4.481403
# 2                   -0.895895                                      -1.800469
# 3                   -0.510109                                      -8.705812
# 4                   -0.233128                                      -0.880283
# 5                   -1.321998                                      -2.364570
# 6                   -0.900507                                      -8.961262
# 7                    0.000000                                       0.000000
# 8                   -1.211088                                       5.551417
# 9                   -0.270345                                      -0.638260
# 10                  -0.267777                                      -0.603325
# 11                  -1.116446                                       4.784390
# 12                  -0.653308                                      -1.635237
# 13                  -0.950195                                      -1.639505
# 14                  -0.250341                                      -0.346983
# 15                  -0.322743                                      -0.972495
# 16                  -0.440866                                      -1.729267
# 17                  -1.347492                                      -2.153293
# 18                  -1.046700                                      -1.773480
# 19                  -0.224152                                      -0.489408
#
#     Ca interaction energy, charged sidechains, eV  \
# 0                                       -0.118715
# 1                                        4.390957
# 2                                       -1.256246
# 3                                       -8.138319
# 4                                       -0.458234
# 5                                       -1.721022
# 6                                       -8.330724
# 7                                        0.000000
# 8                                        5.389953
# 9                                       -0.347956
# 10                                      -0.306301
# 11                                       4.692650
# 12                                      -0.978467
# 13                                      -1.262397
# 14                                      -0.304477
# 15                                      -0.578240
# 16                                      -0.720148
# 17                                      -1.679008
# 18                                      -1.381339
# 19                                      -0.271099
#
#     Ba interaction energy, charged sidechains, eV
# 0                                       -0.100234
# 1                                        4.303165
# 2                                       -0.895895
# 3                                       -7.615657
# 4                                       -0.233128
# 5                                       -1.321998
# 6                                       -7.762967
# 7                                        0.000000
# 8                                        5.226539
# 9                                       -0.270345
# 10                                      -0.267777
# 11                                       4.603275
# 12                                      -0.653308
# 13                                      -0.950195
# 14                                      -0.250341
# 15                                      -0.322743
# 16                                      -0.440866
# 17                                      -1.347492
# 18                                      -1.046700
# 19                                      -0.224152

# %%
# save
edf.to_csv('data/energies.csv', index=False)
